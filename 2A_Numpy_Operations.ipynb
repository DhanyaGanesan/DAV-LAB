# %%
import numpy as np
print(np.__version__)
# Out:
# 2.3.2

# %%
import numpy as np

print("NumPy Version:", np.__version__)

arr_1d = np.array([1, 2, 3, 4, 5])
arr_2d = np.array([[1, 2, 3], [4, 5, 6]])
arr_0d = np.array(42)
arr_ones = np.ones((3, 3))

print("Element at index 2:", arr_1d[2])
print("Element at row 1, column 2:", arr_2d[1, 2])

print("Slice:", arr_1d[1:4])

arr_a = np.array([10, 20, 30])
arr_b = np.array([1, 2, 3])

print("Addition:", arr_a + arr_b)
print("Subtraction:", arr_a - arr_b)
print("Multiplication:", arr_a * arr_b)
print("Division:", arr_a / arr_b)

print("Sum:", np.sum(arr_a))
print("Mean:", np.mean(arr_a))
print("Standard Deviation:", np.std(arr_a))
# Out:
# NumPy Version: 2.3.2
# Element at index 2: 3
# Element at row 1, column 2: 6
# Slice: [2 3 4]
# Addition: [11 22 33]
# Subtraction: [ 9 18 27]
# Multiplication: [10 40 90]
# Division: [10. 10. 10.]
# Sum: 60
# Mean: 20.0
# Standard Deviation: 8.16496580927726

# %%
import pandas as pd
print(pd.__version__)
# Out:
# 2.3.1

# %%
import pandas as pd

data = {
    'existing_column': [60, 45, 80, 55, 90],
    'another_column': [90, 110, 70, 85, 60],
    'category_column': ['A', 'B', 'A', 'B', 'A'],
    'numeric_column': [100, 200, 150, 120, 180],
    'column1': ['X', 'Y', 'Z', 'P', 'Q'],
    'column2': [10, 20, 30, 40, 50]
}

df = pd.DataFrame(data)

df.to_csv('data.csv', index=False)

print("data.csv created successfully")
# Out:
# data.csv created successfully

# %%
import pandas as pd

# Load dataset
df = pd.read_csv('data.csv')

# First and last rows
print("First 5 rows:\n", df.head())
print("\nLast 5 rows:\n", df.tail())

# Data types and information
print("\nDataFrame Info:")
df.info()

# Summary statistics
print("\nSummary Statistics:")
print(df.describe())

# Handle missing values
df.fillna(df.mean(numeric_only=True), inplace=True)

# Create new column
df['new_column'] = df['existing_column'] * 2

# Series operations
series = df['existing_column']
print("\nSeries + 10:")
print(series + 10)

# Filtering
filtered_df = df[(df['existing_column'] > 50) &
                 (df['another_column'] < 100)]

print("\nFiltered DataFrame:")
print(filtered_df)

# Grouping and aggregation
grouped = df.groupby('category_column')['numeric_column'].mean()

print("\nGrouped Mean:")
print(grouped)

# Sorting
df_sorted = df.sort_values(by='numeric_column',
                           ascending=False)

print("\nSorted DataFrame:")
print(df_sorted)

# Boolean masking
masked_df = df[df['numeric_column'] >
               df['numeric_column'].median()]

print("\nMasked DataFrame:")
print(masked_df)

# Remove duplicates and missing values
df.drop_duplicates(inplace=True)
df.dropna(inplace=True)

# Subset DataFrame
subset_df = df[['column1', 'column2']]

# Save to CSV
subset_df.to_csv('filtered_data.csv', index=False)

# Statistics
print("\nTotal Sum:", df['numeric_column'].sum())
print("Mean:", df['numeric_column'].mean())
print("Standard Deviation:",
      df['numeric_column'].std())
# Out:
# First 5 rows:
#     existing_column  another_column category_column  numeric_column column1  \
# 0               60              90               A             100       X
# 1               45             110               B             200       Y
# 2               80              70               A             150       Z
# 3               55              85               B             120       P
# 4               90              60               A             180       Q
#
#    column2
# 0       10
# 1       20
# 2       30
# 3       40
# 4       50
#
# Last 5 rows:
#     existing_column  another_column category_column  numeric_column column1  \
# 0               60              90               A             100       X
# 1               45             110               B             200       Y
# 2               80              70               A             150       Z
# 3               55              85               B             120       P
# 4               90              60               A             180       Q
#
#    column2
# 0       10
# 1       20
# 2       30
# 3       40
# 4       50
#
# DataFrame Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 6 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   existing_column  5 non-null      int64
#  1   another_column   5 non-null      int64
#  2   category_column  5 non-null      object
#  3   numeric_column   5 non-null      int64
#  4   column1          5 non-null      object
#  5   column2          5 non-null      int64
# dtypes: int64(4), object(2)
# memory usage: 372.0+ bytes
#
# Summary Statistics:
#        existing_column  another_column  numeric_column    column2
# count         5.000000        5.000000        5.000000   5.000000
# mean         66.000000       83.000000      150.000000  30.000000
# std          18.506756       19.235384       41.231056  15.811388
# min          45.000000       60.000000      100.000000  10.000000
# 25%          55.000000       70.000000      120.000000  20.000000
# 50%          60.000000       85.000000      150.000000  30.000000
# 75%          80.000000       90.000000      180.000000  40.000000
# max          90.000000      110.000000      200.000000  50.000000
#
# Series + 10:
# 0     70
# 1     55
# 2     90
# 3     65
# 4    100
# Name: existing_column, dtype: int64
#
# Filtered DataFrame:
#    existing_column  another_column category_column  numeric_column column1  \
# 0               60              90               A             100       X
# 2               80              70               A             150       Z
# 3               55              85               B             120       P
# 4               90              60               A             180       Q
#
#    column2  new_column
# 0       10         120
# 2       30         160
# 3       40         110
# 4       50         180
#
# Grouped Mean:
# category_column
# A    143.333333
# B    160.000000
# Name: numeric_column, dtype: float64
#
# Sorted DataFrame:
#    existing_column  another_column category_column  numeric_column column1  \
# 1               45             110               B             200       Y
# 4               90              60               A             180       Q
# 2               80              70               A             150       Z
# 3               55              85               B             120       P
# 0               60              90               A             100       X
#
#    column2  new_column
# 1       20          90
# 4       50         180
# 2       30         160
# 3       40         110
# 0       10         120
#
# Masked DataFrame:
#    existing_column  another_column category_column  numeric_column column1  \
# 1               45             110               B             200       Y
# 4               90              60               A             180       Q
#
#    column2  new_column
# 1       20          90
# 4       50         180
#
# Total Sum: 750
# Mean: 150.0
# Standard Deviation: 41.23105625617661
