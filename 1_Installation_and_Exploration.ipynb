# %%
# %pip install numpy scipy jupyter statsmodels pandas matplotlib seaborn plotly bokeh jupyterlab
# Out:
# Requirement already satisfied: numpy in c:\users\dhanya\appdata\local\programs\python\python313\lib\site-packages (2.3.2)
# Requirement already satisfied: scipy in c:\users\dhanya\appdata\local\programs\python\python313\lib\site-packages (1.16.1)
# Collecting jupyter
#   Using cached jupyter-1.1.1-py2.py3-none-any.whl.metadata (2.0 kB)
# Requirement already satisfied: statsmodels in c:\users\dhanya\appdata\local\programs\python\python313\lib\site-packages (0.14.6)
# Requirement already satisfied: pandas in c:\users\dhanya\appdata\local\programs\python\python313\lib\site-packages (2.3.1)
# Requirement already satisfied: matplotlib in c:\users\dhanya\appdata\local\programs\python\python313\lib\site-packages (3.10.5)
# Requirement already satisfied: seaborn in c:\users\dhanya\appdata\local\programs\python\python313\lib\site-packages (0.13.2)
# Requirement already satisfied: plotly in c:\users\dhanya\appdata\local\programs\python\python313\lib\site-packages (6.9.0)
# Collecting bokeh
#   Using cached bokeh-3.9.2-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: jupyterlab in c:\users\dhanya\appdata\local\programs\python\python313\lib\site-packages (4.6.0)
# Requirement already satisfied: notebook in c:\users\dhanya\appdata\local\programs\python\python313\lib\site-packages (from jupyter) (7.6.0)
# Collecting jupyter-console (from jupyter)
#   Using cached jupyter_console-6.6.3-py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: nbconvert in c:\users\dhanya\appdata\local\programs\python\python313\lib\site-packages (from jupyter) (7.17.1)
# Requirement already satisfied: ipykernel in c:\users\dhanya\appdata\local\programs\python\python313\lib\site-packages (from jupyter) (7.3.0)
# Collecting ipywidgets (from jupyter)
#   Using cached ipywidgets-8.1.8-py3-none-any.whl.metadata (2.4 kB)
# Requirement already satisfied: patsy>=0.5.6 in c:\users\dhanya\appdata\local\programs\python\python313\lib\site-packages (from statsmodels) (1.0.2)
# Requirement already satisfied: packaging>=21.3 in c:\users\dhanya\appdata\local\programs\python\python313\lib\site-packages (from statsmodels) (25.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\dhanya\appdata\local\programs\python\python313\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\dhanya\appdata\local\programs\python\python313\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\dhanya\appdata\local\programs\python\python313\lib\site-packages (from pandas) (2025.1)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\dhanya\appdata\local\programs\python\python313\lib\site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\dhanya\appdata\local\programs\python\python313\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\dhanya\appdata\local\programs\python\python313\lib\site-packages (from matplotlib) (4.59.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\dhanya\appdata\local\programs\python\python313\lib\site-packages (from matplotlib) (1.4.8)
# Requirement already satisfied: pillow>=8 in c:\users\dhanya\appdata\local\programs\python\python313\lib\site-packages (from matplotlib) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\dhanya\appdata\local\programs\python\python313\lib\site-packages (from matplotlib) (3.2.3)
# Requirement already satisfied: narwhals>=1.15.1 in c:\users\dhanya\appdata\local\programs\python\python313\lib\site-packages (from plotly) (2.24.0)
# Requirement already satisfied: Jinja2>=2.9 in c:\users\dhanya\appdata\local\programs\python\python313\lib\site-packages (from bokeh) (3.1.6)
# Requirement already satisfied: PyYAML>=3.10 in c:\users\dhanya\appdata\local\programs\python\python313\lib\site-packages (from bokeh) (6.0.3)
# Requirement already satisfied: tornado>=6.2 in c:\users\dhanya\appdata\local\programs\python\python313\lib\site-packages (from bokeh) (6.5.7)
# Requirement already satisfied: xyzservices>=2021.09.1 in c:\users\dhanya\appdata\local\programs\python\python313\lib\site-packages (from bokeh) (2026.3.0)
# Requirement already satisfied: async-lru>=1.0.0 in c:\users\dhanya\appdata\local\programs\python\python313\lib\site-packages (from jupyterlab) (2.3.0)
# Requirement already satisfied: httpx<1,>=0.25.0 in c:\users\dhanya\appdata\local\programs\python\python313\lib\site-packages (from jupyterlab) (0.28.1)
# Requirement already satisfied: jupyter-builder>=1.0.2 in c:\users\dhanya\appdata\local\programs\python\python313\lib\site-packages (from jupyterlab) (1.0.2)
# Requirement already satisfied: jupyter-core in c:\users\dhanya\appdata\local\programs\python\python313\lib\site-packages (from jupyterlab) (5.9.1)
# Requirement already satisfied: jupyter-lsp>=2.0.0 in c:\users\dhanya\appdata\local\programs\python\python313\lib\site-packages (from jupyterlab) (2.3.1)
# Requirement already satisfied: jupyter-server<3,>=2.19.0 in c:\users\dhanya\appdata\local\programs\python\python313\lib\site-packages (from jupyterlab) (2.20.0)
# Requirement already satisfied: jupyterlab-server<3,>=2.28.0 in c:\users\dhanya\appdata\local\programs\python\python313\lib\site-packages (from jupyterlab) (2.28.0)
# Requirement already satisfied: notebook-shim>=0.2 in c:\users\dhanya\appdata\local\programs\python\python313\lib\site-packages (from jupyterlab) (0.2.4)
# Requirement already satisfied: traitlets in c:\users\dhanya\appdata\local\programs\python\python313\lib\site-packages (from jupyterlab) (5.15.1)
# Requirement already satisfied: anyio in c:\users\dhanya\appdata\local\programs\python\python313\lib\site-packages (from httpx<1,>=0.25.0->jupyterlab) (4.10.0)
# Requirement already satisfied: certifi in c:\users\dhanya\appdata\local\programs\python\python313\lib\site-packages (from httpx<1,>=0.25.0->jupyterlab) (2026.6.17)
# Requirement already satisfied: httpcore==1.* in c:\users\dhanya\appdata\local\programs\python\python313\lib\site-packages (from httpx<1,>=0.25.0->jupyterlab) (1.0.9)
# Requirement already satisfied: idna in c:\users\dhanya\appdata\local\programs\python\python313\lib\site-packages (from httpx<1,>=0.25.0->jupyterlab) (3.10)
# Requirement already satisfied: h11>=0.16 in c:\users\dhanya\appdata\local\programs\python\python313\lib\site-packages (from httpcore==1.*->httpx<1,>=0.25.0->jupyterlab) (0.16.0)
# Requirement already satisfied: argon2-cffi>=21.1 in c:\users\dhanya\appdata\local\programs\python\python313\lib\site-packages (from jupyter-server<3,>=2.19.0->jupyterlab) (25.1.0)
# Requirement already satisfied: jupyter-client>=7.4.4 in c:\users\dhanya\appdata\local\programs\python\python313\lib\site-packages (from jupyter-server<3,>=2.19.0->jupyterlab) (8.9.1)
# Requirement already satisfied: jupyter-events>=0.11.0 in c:\users\dhanya\appdata\local\programs\python\python313\lib\site-packages (from jupyter-server<3,>=2.19.0->jupyterlab) (0.12.1)
# Requirement already satisfied: jupyter-server-terminals>=0.4.4 in c:\users\dhanya\appdata\local\programs\python\python313\lib\site-packages (from jupyter-server<3,>=2.19.0->jupyterlab) (0.5.4)
# Requirement already satisfied: nbformat>=5.3.0 in c:\users\dhanya\appdata\local\programs\python\python313\lib\site-packages (from jupyter-server<3,>=2.19.0->jupyterlab) (5.10.4)
# Requirement already satisfied: prometheus-client>=0.9 in c:\users\dhanya\appdata\local\programs\python\python313\lib\site-packages (from jupyter-server<3,>=2.19.0->jupyterlab) (0.25.0)
# Requirement already satisfied: pywinpty!=3.0.4,>=2.0.1 in c:\users\dhanya\appdata\local\programs\python\python313\lib\site-packages (from jupyter-server<3,>=2.19.0->jupyterlab) (3.0.5)
# Requirement already satisfied: pyzmq>=24 in c:\users\dhanya\appdata\local\programs\python\python313\lib\site-packages (from jupyter-server<3,>=2.19.0->jupyterlab) (27.1.0)
# Requirement already satisfied: send2trash>=1.8.2 in c:\users\dhanya\appdata\local\programs\python\python313\lib\site-packages (from jupyter-server<3,>=2.19.0->jupyterlab) (2.1.0)
# Requirement already satisfied: terminado>=0.8.3 in c:\users\dhanya\appdata\local\programs\python\python313\lib\site-packages (from jupyter-server<3,>=2.19.0->jupyterlab) (0.18.1)
# Requirement already satisfied: websocket-client>=1.7 in c:\users\dhanya\appdata\local\programs\python\python313\lib\site-packages (from jupyter-server<3,>=2.19.0->jupyterlab) (1.9.0)
# Requirement already satisfied: babel>=2.10 in c:\users\dhanya\appdata\local\programs\python\python313\lib\site-packages (from jupyterlab-server<3,>=2.28.0->jupyterlab) (2.18.0)
# Requirement already satisfied: json5>=0.9.0 in c:\users\dhanya\appdata\local\programs\python\python313\lib\site-packages (from jupyterlab-server<3,>=2.28.0->jupyterlab) (0.15.0)
# Requirement already satisfied: jsonschema>=4.18.0 in c:\users\dhanya\appdata\local\programs\python\python313\lib\site-packages (from jupyterlab-server<3,>=2.28.0->jupyterlab) (4.26.0)
# Requirement already satisfied: requests>=2.31 in c:\users\dhanya\appdata\local\programs\python\python313\lib\site-packages (from jupyterlab-server<3,>=2.28.0->jupyterlab) (2.34.2)
# Requirement already satisfied: sniffio>=1.1 in c:\users\dhanya\appdata\local\programs\python\python313\lib\site-packages (from anyio->httpx<1,>=0.25.0->jupyterlab) (1.3.1)
# Requirement already satisfied: argon2-cffi-bindings in c:\users\dhanya\appdata\local\programs\python\python313\lib\site-packages (from argon2-cffi>=21.1->jupyter-server<3,>=2.19.0->jupyterlab) (25.1.0)
# Requirement already satisfied: comm>=0.1.1 in c:\users\dhanya\appdata\local\programs\python\python313\lib\site-packages (from ipykernel->jupyter) (0.2.3)
# Requirement already satisfied: debugpy>=1.6.5 in c:\users\dhanya\appdata\local\programs\python\python313\lib\site-packages (from ipykernel->jupyter) (1.8.21)
# Requirement already satisfied: ipython>=7.23.1 in c:\users\dhanya\appdata\local\programs\python\python313\lib\site-packages (from ipykernel->jupyter) (9.14.1)
# Requirement already satisfied: matplotlib-inline>=0.1 in c:\users\dhanya\appdata\local\programs\python\python313\lib\site-packages (from ipykernel->jupyter) (0.2.2)
# Requirement already satisfied: nest-asyncio2>=1.7.0 in c:\users\dhanya\appdata\local\programs\python\python313\lib\site-packages (from ipykernel->jupyter) (1.7.2)
# Requirement already satisfied: psutil>=5.7 in c:\users\dhanya\appdata\local\programs\python\python313\lib\site-packages (from ipykernel->jupyter) (7.2.2)
# Requirement already satisfied: colorama>=0.4.4 in c:\users\dhanya\appdata\local\programs\python\python313\lib\site-packages (from ipython>=7.23.1->ipykernel->jupyter) (0.4.6)
# Requirement already satisfied: decorator>=5.1.0 in c:\users\dhanya\appdata\local\programs\python\python313\lib\site-packages (from ipython>=7.23.1->ipykernel->jupyter) (5.3.1)
# Requirement already satisfied: ipython-pygments-lexers>=1.0.0 in c:\users\dhanya\appdata\local\programs\python\python313\lib\site-packages (from ipython>=7.23.1->ipykernel->jupyter) (1.1.1)
# Requirement already satisfied: jedi>=0.18.2 in c:\users\dhanya\appdata\local\programs\python\python313\lib\site-packages (from ipython>=7.23.1->ipykernel->jupyter) (0.20.0)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in c:\users\dhanya\appdata\local\programs\python\python313\lib\site-packages (from ipython>=7.23.1->ipykernel->jupyter) (3.0.52)
# Requirement already satisfied: pygments>=2.14.0 in c:\users\dhanya\appdata\local\programs\python\python313\lib\site-packages (from ipython>=7.23.1->ipykernel->jupyter) (2.20.0)
# Requirement already satisfied: stack_data>=0.6.0 in c:\users\dhanya\appdata\local\programs\python\python313\lib\site-packages (from ipython>=7.23.1->ipykernel->jupyter) (0.6.3)
# Requirement already satisfied: wcwidth in c:\users\dhanya\appdata\local\programs\python\python313\lib\site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython>=7.23.1->ipykernel->jupyter) (0.8.1)
# Requirement already satisfied: parso<0.9.0,>=0.8.6 in c:\users\dhanya\appdata\local\programs\python\python313\lib\site-packages (from jedi>=0.18.2->ipython>=7.23.1->ipykernel->jupyter) (0.8.7)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\dhanya\appdata\local\programs\python\python313\lib\site-packages (from Jinja2>=2.9->bokeh) (3.0.3)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\dhanya\appdata\local\programs\python\python313\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.28.0->jupyterlab) (26.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\dhanya\appdata\local\programs\python\python313\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.28.0->jupyterlab) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\dhanya\appdata\local\programs\python\python313\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.28.0->jupyterlab) (0.37.0)
# Requirement already satisfied: rpds-py>=0.25.0 in c:\users\dhanya\appdata\local\programs\python\python313\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.28.0->jupyterlab) (2026.5.1)
# Requirement already satisfied: typing-extensions>=4.13.0 in c:\users\dhanya\appdata\local\programs\python\python313\lib\site-packages (from jupyter-client>=7.4.4->jupyter-server<3,>=2.19.0->jupyterlab) (4.15.0)
# Requirement already satisfied: platformdirs>=2.5 in c:\users\dhanya\appdata\local\programs\python\python313\lib\site-packages (from jupyter-core->jupyterlab) (4.10.0)
# Requirement already satisfied: python-json-logger>=2.0.4 in c:\users\dhanya\appdata\local\programs\python\python313\lib\site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.19.0->jupyterlab) (4.1.0)
# Requirement already satisfied: rfc3339-validator in c:\users\dhanya\appdata\local\programs\python\python313\lib\site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.19.0->jupyterlab) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in c:\users\dhanya\appdata\local\programs\python\python313\lib\site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.19.0->jupyterlab) (0.1.1)
# Requirement already satisfied: fqdn in c:\users\dhanya\appdata\local\programs\python\python313\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.19.0->jupyterlab) (1.5.1)
# Requirement already satisfied: isoduration in c:\users\dhanya\appdata\local\programs\python\python313\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.19.0->jupyterlab) (20.11.0)
# Requirement already satisfied: jsonpointer>1.13 in c:\users\dhanya\appdata\local\programs\python\python313\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.19.0->jupyterlab) (3.1.1)
# Requirement already satisfied: rfc3987-syntax>=1.1.0 in c:\users\dhanya\appdata\local\programs\python\python313\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.19.0->jupyterlab) (1.1.0)
# Requirement already satisfied: uri-template in c:\users\dhanya\appdata\local\programs\python\python313\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.19.0->jupyterlab) (1.3.0)
# Requirement already satisfied: webcolors>=24.6.0 in c:\users\dhanya\appdata\local\programs\python\python313\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.19.0->jupyterlab) (25.10.0)
# Requirement already satisfied: beautifulsoup4 in c:\users\dhanya\appdata\local\programs\python\python313\lib\site-packages (from nbconvert->jupyter) (4.15.0)
# Requirement already satisfied: bleach!=5.0.0 in c:\users\dhanya\appdata\local\programs\python\python313\lib\site-packages (from bleach[css]!=5.0.0->nbconvert->jupyter) (6.4.0)
# Requirement already satisfied: defusedxml in c:\users\dhanya\appdata\local\programs\python\python313\lib\site-packages (from nbconvert->jupyter) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in c:\users\dhanya\appdata\local\programs\python\python313\lib\site-packages (from nbconvert->jupyter) (0.3.0)
# Requirement already satisfied: mistune<4,>=2.0.3 in c:\users\dhanya\appdata\local\programs\python\python313\lib\site-packages (from nbconvert->jupyter) (3.3.2)
# Requirement already satisfied: nbclient>=0.5.0 in c:\users\dhanya\appdata\local\programs\python\python313\lib\site-packages (from nbconvert->jupyter) (0.11.0)
# Requirement already satisfied: pandocfilters>=1.4.1 in c:\users\dhanya\appdata\local\programs\python\python313\lib\site-packages (from nbconvert->jupyter) (1.5.1)
# Requirement already satisfied: webencodings in c:\users\dhanya\appdata\local\programs\python\python313\lib\site-packages (from bleach!=5.0.0->bleach[css]!=5.0.0->nbconvert->jupyter) (0.5.1)
# Requirement already satisfied: tinycss2>=1.1.0 in c:\users\dhanya\appdata\local\programs\python\python313\lib\site-packages (from bleach[css]!=5.0.0->nbconvert->jupyter) (1.5.1)
# Requirement already satisfied: fastjsonschema>=2.15 in c:\users\dhanya\appdata\local\programs\python\python313\lib\site-packages (from nbformat>=5.3.0->jupyter-server<3,>=2.19.0->jupyterlab) (2.21.2)
# Requirement already satisfied: six>=1.5 in c:\users\dhanya\appdata\local\programs\python\python313\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\dhanya\appdata\local\programs\python\python313\lib\site-packages (from requests>=2.31->jupyterlab-server<3,>=2.28.0->jupyterlab) (3.4.7)
# Requirement already satisfied: urllib3<3,>=1.26 in c:\users\dhanya\appdata\local\programs\python\python313\lib\site-packages (from requests>=2.31->jupyterlab-server<3,>=2.28.0->jupyterlab) (2.7.0)
# Requirement already satisfied: lark>=1.2.2 in c:\users\dhanya\appdata\local\programs\python\python313\lib\site-packages (from rfc3987-syntax>=1.1.0->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.19.0->jupyterlab) (1.3.1)
# Requirement already satisfied: executing>=1.2.0 in c:\users\dhanya\appdata\local\programs\python\python313\lib\site-packages (from stack_data>=0.6.0->ipython>=7.23.1->ipykernel->jupyter) (2.2.1)
# Requirement already satisfied: asttokens>=2.1.0 in c:\users\dhanya\appdata\local\programs\python\python313\lib\site-packages (from stack_data>=0.6.0->ipython>=7.23.1->ipykernel->jupyter) (3.0.1)
# Requirement already satisfied: pure-eval in c:\users\dhanya\appdata\local\programs\python\python313\lib\site-packages (from stack_data>=0.6.0->ipython>=7.23.1->ipykernel->jupyter) (0.2.3)
# Requirement already satisfied: cffi>=1.0.1 in c:\users\dhanya\appdata\local\programs\python\python313\lib\site-packages (from argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.19.0->jupyterlab) (2.0.0)
# Requirement already satisfied: pycparser in c:\users\dhanya\appdata\local\programs\python\python313\lib\site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.19.0->jupyterlab) (2.23)
# Requirement already satisfied: soupsieve>=1.6.1 in c:\users\dhanya\appdata\local\programs\python\python313\lib\site-packages (from beautifulsoup4->nbconvert->jupyter) (2.8.4)
# Requirement already satisfied: widgetsnbextension~=4.0.14 in c:\users\dhanya\appdata\local\programs\python\python313\lib\site-packages (from ipywidgets->jupyter) (4.0.15)
# Requirement already satisfied: jupyterlab_widgets~=3.0.15 in c:\users\dhanya\appdata\local\programs\python\python313\lib\site-packages (from ipywidgets->jupyter) (3.0.16)
# Requirement already satisfied: arrow>=0.15.0 in c:\users\dhanya\appdata\local\programs\python\python313\lib\site-packages (from isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.19.0->jupyterlab) (1.4.0)
# Using cached jupyter-1.1.1-py2.py3-none-any.whl (2.7 kB)
# Using cached bokeh-3.9.2-py3-none-any.whl (6.4 MB)
# Using cached ipywidgets-8.1.8-py3-none-any.whl (139 kB)
# Using cached jupyter_console-6.6.3-py3-none-any.whl (24 kB)
# Installing collected packages: bokeh, ipywidgets, jupyter-console, jupyter
#
#    ---------------------------------------- 0/4 [bokeh]
#    ---------------------------------------- 0/4 [bokeh]
#    ---------------------------------------- 0/4 [bokeh]
#    ---------------------------------------- 0/4 [bokeh]
#    ---------------------------------------- 0/4 [bokeh]
#    ---------------------------------------- 0/4 [bokeh]
#    ---------------------------------------- 0/4 [bokeh]
#    ---------------------------------------- 0/4 [bokeh]
#    ---------------------------------------- 0/4 [bokeh]
#    ---------------------------------------- 0/4 [bokeh]
#    ---------------------------------------- 0/4 [bokeh]
#    ---------------------------------------- 0/4 [bokeh]
#    ---------------------------------------- 0/4 [bokeh]
#    ---------------------------------------- 0/4 [bokeh]
#    ---------------------------------------- 0/4 [bokeh]
#    ---------------------------------------- 0/4 [bokeh]
#    ---------------------------------------- 0/4 [bokeh]
#    ---------------------------------------- 0/4 [bokeh]
#    ---------------------------------------- 0/4 [bokeh]
#    ---------------------------------------- 0/4 [bokeh]
#    ---------------------------------------- 0/4 [bokeh]
#    ---------------------------------------- 0/4 [bokeh]
#    ---------------------------------------- 0/4 [bokeh]
#    ---------------------------------------- 0/4 [bokeh]
#    ---------------------------------------- 0/4 [bokeh]
#    ---------------------------------------- 0/4 [bokeh]
#    ---------------------------------------- 0/4 [bokeh]
#    ---------------------------------------- 0/4 [bokeh]
#    ---------------------------------------- 0/4 [bokeh]
#    ---------------------------------------- 0/4 [bokeh]
#    ---------------------------------------- 0/4 [bokeh]
#    ---------------------------------------- 0/4 [bokeh]
#    ---------------------------------------- 0/4 [bokeh]
#    ---------------------------------------- 0/4 [bokeh]
#    ---------------------------------------- 0/4 [bokeh]
#    ---------------------------------------- 0/4 [bokeh]
#    ---------------------------------------- 0/4 [bokeh]
#    ---------------------------------------- 0/4 [bokeh]
#    ---------------------------------------- 0/4 [bokeh]
#    ---------------------------------------- 0/4 [bokeh]
#    ---------------------------------------- 0/4 [bokeh]
#    ---------------------------------------- 0/4 [bokeh]
#    ---------------------------------------- 0/4 [bokeh]
#    ---------------------------------------- 0/4 [bokeh]
#    ---------------------------------------- 0/4 [bokeh]
#    ---------------------------------------- 0/4 [bokeh]
#    ---------------------------------------- 0/4 [bokeh]
#    ---------------------------------------- 0/4 [bokeh]
#    ---------------------------------------- 0/4 [bokeh]
#    ---------------------------------------- 0/4 [bokeh]
#    ---------------------------------------- 0/4 [bokeh]
#    ---------------------------------------- 0/4 [bokeh]
#    ---------------------------------------- 0/4 [bokeh]
#    ---------------------------------------- 0/4 [bokeh]
#    ---------------------------------------- 0/4 [bokeh]
#    ---------------------------------------- 0/4 [bokeh]
#    ---------------------------------------- 0/4 [bokeh]
#    ---------------------------------------- 0/4 [bokeh]
#    ---------------------------------------- 0/4 [bokeh]
#    ---------------------------------------- 0/4 [bokeh]
#    ---------------------------------------- 0/4 [bokeh]
#    ---------------------------------------- 0/4 [bokeh]
#    ---------------------------------------- 0/4 [bokeh]
#    ---------------------------------------- 0/4 [bokeh]
#    ---------------------------------------- 0/4 [bokeh]
#    ---------------------------------------- 0/4 [bokeh]
#    ---------------------------------------- 0/4 [bokeh]
#    ---------- ----------------------------- 1/4 [ipywidgets]
#    ---------- ----------------------------- 1/4 [ipywidgets]
#    ---------- ----------------------------- 1/4 [ipywidgets]
#    ---------- ----------------------------- 1/4 [ipywidgets]
#    ---------- ----------------------------- 1/4 [ipywidgets]
#    ---------- ----------------------------- 1/4 [ipywidgets]
#    ---------- ----------------------------- 1/4 [ipywidgets]
#    ---------- ----------------------------- 1/4 [ipywidgets]
#    ---------- ----------------------------- 1/4 [ipywidgets]
#    ---------- ----------------------------- 1/4 [ipywidgets]
#    -------------------- ------------------- 2/4 [jupyter-console]
#    -------------------- ------------------- 2/4 [jupyter-console]
#    ---------------------------------------- 4/4 [jupyter]
#
# Successfully installed bokeh-3.9.2 ipywidgets-8.1.8 jupyter-1.1.1 jupyter-console-6.6.3
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.2 -> 26.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import numpy as np
print("NumPy Version:", np.__version__)

import pandas as pd
print("Pandas Version:", pd.__version__)

import matplotlib
print("Matplotlib Version:", matplotlib.__version__)

import seaborn as sns
print("Seaborn Version:", sns.__version__)

import statsmodels.api as sm
print("Statsmodels Version:", sm.__version__)

import scipy
print("SciPy Version:", scipy.__version__)

import plotly
print("Plotly Version:", plotly.__version__)

import bokeh
print("Bokeh Version:", bokeh.__version__)

import jupyterlab
print("JupyterLab Version:", jupyterlab.__version__)
# Out:
# NumPy Version: 2.3.2
# Pandas Version: 2.3.1
# Matplotlib Version: 3.10.5
